# %%
import numpy
numpy.random.seed(0)

from keras.models import Sequential
from keras.layers import Dense, Dropout, TimeDistributed, Flatten, SimpleRNN,LSTM
import airlineUtils

#set sequence length
history=4

#read training and test sets
trainX, trainY, testX, testY, scaler, dataset=airlineUtils.readAirlineData(history)

# create and fit the LSTM network
modelRNN = Sequential()
modelRNN.add(SimpleRNN(5,input_dim=1,input_length=history, return_sequences=False))
modelRNN.add(Dense(1))

#Train model
modelRNN.compile(loss='mean_squared_error', optimizer='adam')
modelRNN.fit(trainX, trainY, nb_epoch=150, batch_size=5, verbose=2, shuffle=False)

# Make predictions
trainPredict = modelRNN.predict(trainX)
testPredict = modelRNN.predict(testX)

#Display results
airlineUtils.displayResult(dataset, trainPredict, trainY, testPredict, testY, scaler, history)
# Out:
# /datos/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: UserWarning: The `input_dim` and `input_length` arguments in recurrent layers are deprecated. Use `input_shape` instead.
#   app.launch_new_instance()
# /datos/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: UserWarning: Update your `SimpleRNN` call to the Keras 2 API: `SimpleRNN(5, return_sequences=False, input_shape=(4, 1))`
#   app.launch_new_instance()
# /datos/anaconda3/lib/python3.6/site-packages/keras/models.py:848: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/150
# 0s - loss: 0.0089
# Epoch 2/150
# 0s - loss: 0.0072
# Epoch 3/150
# 0s - loss: 0.0067
# Epoch 4/150
# 0s - loss: 0.0065
# Epoch 5/150
# 0s - loss: 0.0063
# Epoch 6/150
# 0s - loss: 0.0062
# Epoch 7/150
# 0s - loss: 0.0061
# Epoch 8/150
# 0s - loss: 0.0060
# Epoch 9/150
# 0s - loss: 0.0059
# Epoch 10/150
# 0s - loss: 0.0059
# Epoch 11/150
# 0s - loss: 0.0058
# Epoch 12/150
# 0s - loss: 0.0057
# Epoch 13/150
# 0s - loss: 0.0056
# Epoch 14/150
# 0s - loss: 0.0055
# Epoch 15/150
# 0s - loss: 0.0054
# Epoch 16/150
# 0s - loss: 0.0054
# Epoch 17/150
# 0s - loss: 0.0053
# Epoch 18/150
# 0s - loss: 0.0052
# Epoch 19/150
# 0s - loss: 0.0052
# Epoch 20/150
# 0s - loss: 0.0051
# Epoch 21/150
# 0s - loss: 0.0051
# Epoch 22/150
# 0s - loss: 0.0050
# Epoch 23/150
# 0s - loss: 0.0049
# Epoch 24/150
# 0s - loss: 0.0049
# Epoch 25/150
# 0s - loss: 0.0048
# Epoch 26/150
# 0s - loss: 0.0048
# Epoch 27/150
# 0s - loss: 0.0048
# Epoch 28/150
# 0s - loss: 0.0047
# Epoch 29/150
# 0s - loss: 0.0047
# Epoch 30/150
# 0s - loss: 0.0046
# Epoch 31/150
# 0s - loss: 0.0046
# Epoch 32/150
# 0s - loss: 0.0045
# Epoch 33/150
# 0s - loss: 0.0045
# Epoch 34/150
# 0s - loss: 0.0045
# Epoch 35/150
# 0s - loss: 0.0044
# Epoch 36/150
# 0s - loss: 0.0044
# Epoch 37/150
# 0s - loss: 0.0044
# Epoch 38/150
# 0s - loss: 0.0043
# Epoch 39/150
# 0s - loss: 0.0043
# Epoch 40/150
# 0s - loss: 0.0043
# Epoch 41/150
# 0s - loss: 0.0043
# Epoch 42/150
# 0s - loss: 0.0042
# Epoch 43/150
# 0s - loss: 0.0042
# Epoch 44/150
# 0s - loss: 0.0042
# Epoch 45/150
# 0s - loss: 0.0042
# Epoch 46/150
# 0s - loss: 0.0041
# Epoch 47/150
# 0s - loss: 0.0041
# Epoch 48/150
# 0s - loss: 0.0041
# Epoch 49/150
# 0s - loss: 0.0041
# Epoch 50/150
# 0s - loss: 0.0040
# Epoch 51/150
# 0s - loss: 0.0040
# Epoch 52/150
# 0s - loss: 0.0040
# Epoch 53/150
# 0s - loss: 0.0040
# Epoch 54/150
# 0s - loss: 0.0040
# Epoch 55/150
# 0s - loss: 0.0039
# Epoch 56/150
# 0s - loss: 0.0039
# Epoch 57/150
# 0s - loss: 0.0039
# Epoch 58/150
# 0s - loss: 0.0039
# Epoch 59/150
# 0s - loss: 0.0039
# Epoch 60/150
# 0s - loss: 0.0038
# Epoch 61/150
# 0s - loss: 0.0038
# Epoch 62/150
# 0s - loss: 0.0038
# Epoch 63/150
# 0s - loss: 0.0038
# Epoch 64/150
# 0s - loss: 0.0038
# Epoch 65/150
# 0s - loss: 0.0037
# Epoch 66/150
# 0s - loss: 0.0037
# Epoch 67/150
# 0s - loss: 0.0037
# Epoch 68/150
# 0s - loss: 0.0037
# Epoch 69/150
# 0s - loss: 0.0037
# Epoch 70/150
# 0s - loss: 0.0037
# Epoch 71/150
# 0s - loss: 0.0036
# Epoch 72/150
# 0s - loss: 0.0036
# Epoch 73/150
# 0s - loss: 0.0036
# Epoch 74/150
# 0s - loss: 0.0036
# Epoch 75/150
# 0s - loss: 0.0036
# Epoch 76/150
# 0s - loss: 0.0036
# Epoch 77/150
# 0s - loss: 0.0036
# Epoch 78/150
# 0s - loss: 0.0035
# Epoch 79/150
# 0s - loss: 0.0035
# Epoch 80/150
# 0s - loss: 0.0035
# Epoch 81/150
# 0s - loss: 0.0035
# Epoch 82/150
# 0s - loss: 0.0035
# Epoch 83/150
# 0s - loss: 0.0035
# Epoch 84/150
# 0s - loss: 0.0035
# Epoch 85/150
# 0s - loss: 0.0034
# Epoch 86/150
# 0s - loss: 0.0034
# Epoch 87/150
# 0s - loss: 0.0034
# Epoch 88/150
# 0s - loss: 0.0034
# Epoch 89/150
# 0s - loss: 0.0034
# Epoch 90/150
# 0s - loss: 0.0034
# Epoch 91/150
# 0s - loss: 0.0034
# Epoch 92/150
# 0s - loss: 0.0033
# Epoch 93/150
# 0s - loss: 0.0033
# Epoch 94/150
# 0s - loss: 0.0033
# Epoch 95/150
# 0s - loss: 0.0033
# Epoch 96/150
# 0s - loss: 0.0033
# Epoch 97/150
# 0s - loss: 0.0033
# Epoch 98/150
# 0s - loss: 0.0033
# Epoch 99/150
# 0s - loss: 0.0033
# Epoch 100/150
# 0s - loss: 0.0032
# Epoch 101/150
# 0s - loss: 0.0032
# Epoch 102/150
# 0s - loss: 0.0032
# Epoch 103/150
# 0s - loss: 0.0032
# Epoch 104/150
# 0s - loss: 0.0032
# Epoch 105/150
# 0s - loss: 0.0032
# Epoch 106/150
# 0s - loss: 0.0032
# Epoch 107/150
# 0s - loss: 0.0032
# Epoch 108/150
# 0s - loss: 0.0032
# Epoch 109/150
# 0s - loss: 0.0031
# Epoch 110/150
# 0s - loss: 0.0031
# Epoch 111/150
# 0s - loss: 0.0031
# Epoch 112/150
# 0s - loss: 0.0031
# Epoch 113/150
# 0s - loss: 0.0031
# Epoch 114/150
# 0s - loss: 0.0031
# Epoch 115/150
# 0s - loss: 0.0031
# Epoch 116/150
# 0s - loss: 0.0031
# Epoch 117/150
# 0s - loss: 0.0031
# Epoch 118/150
# 0s - loss: 0.0030
# Epoch 119/150
# 0s - loss: 0.0030
# Epoch 120/150
# 0s - loss: 0.0030
# Epoch 121/150
# 0s - loss: 0.0030
# Epoch 122/150
# 0s - loss: 0.0030
# Epoch 123/150
# 0s - loss: 0.0030
# Epoch 124/150
# 0s - loss: 0.0030
# Epoch 125/150
# 0s - loss: 0.0030
# Epoch 126/150
# 0s - loss: 0.0030
# Epoch 127/150
# 0s - loss: 0.0030
# Epoch 128/150
# 0s - loss: 0.0029
# Epoch 129/150
# 0s - loss: 0.0029
# Epoch 130/150
# 0s - loss: 0.0029
# Epoch 131/150
# 0s - loss: 0.0029
# Epoch 132/150
# 0s - loss: 0.0029
# Epoch 133/150
# 0s - loss: 0.0029
# Epoch 134/150
# 0s - loss: 0.0029
# Epoch 135/150
# 0s - loss: 0.0029
# Epoch 136/150
# 0s - loss: 0.0029
# Epoch 137/150
# 0s - loss: 0.0029
# Epoch 138/150
# 0s - loss: 0.0029
# Epoch 139/150
# 0s - loss: 0.0028
# Epoch 140/150
# 0s - loss: 0.0028
# Epoch 141/150
# 0s - loss: 0.0028
# Epoch 142/150
# 0s - loss: 0.0028
# Epoch 143/150
# 0s - loss: 0.0028
# Epoch 144/150
# 0s - loss: 0.0028
# Epoch 145/150
# 0s - loss: 0.0028
# Epoch 146/150
# 0s - loss: 0.0028
# Epoch 147/150
# 0s - loss: 0.0028
# Epoch 148/150
# 0s - loss: 0.0028
# Epoch 149/150
# 0s - loss: 0.0028
# Epoch 150/150
# 0s - loss: 0.0028
# Train Score: 26.71 RMSE
# Test Score: 83.95 RMSE
